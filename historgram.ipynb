# %%
import dash_core_components as dcc
import pandas as pd
import plotly.graph_objs as go
import plotly.express as px

# %%
df = pd.read_csv(
    './testData/chatter.csv')

# %%
df['transactionTime']
# Out:
# 0      2019-03-15 04:02:31
# 1      2019-09-20 03:39:10
# 2      2019-02-24 08:59:08
# 3      2019-07-15 10:51:20
# 4      2019-07-20 10:24:28
#               ...
# 472    2019-08-30 13:25:04
# 473    2019-10-19 13:15:34
# 474    2019-05-12 23:02:36
# 475    2019-06-30 17:52:23
# 476    2019-03-22 14:04:14
# Name: transactionTime, Length: 477, dtype: object

# %%
fig = px.histogram(df, x=df['transactionTime'], 
                   color=df['username'])
fig.show()
# Out:
# <div>
#
#
#             <div id="b2eba5e5-b41c-4a8c-bd82-bd0b2e44a2e7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b2eba5e5-b41c-4a8c-bd82-bd0b2e44a2e7")) {
#                     Plotly.newPlot(
#                         'b2eba5e5-b41c-4a8c-bd82-bd0b2e44a2e7',
# ...
